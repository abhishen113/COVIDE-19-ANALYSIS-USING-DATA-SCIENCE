# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'G:\my video lecture\projects\cv19.csv')

# %%
data = pd.read_csv(r'G:\my video lecture\projects\covid19_italy.csv')

# %%
data
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 22912  22912  2020-08-12T17:00:00     ITA           5     Veneto
# 22913  22913  2020-08-12T17:00:00     ITA           5     Veneto
# 22914  22914  2020-08-12T17:00:00     ITA           5     Veneto
# 22915  22915  2020-08-12T17:00:00     ITA           5     Veneto
# 22916  22916  2020-08-12T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %%
data.tail()
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 22912  22912  2020-08-12T17:00:00     ITA           5     Veneto
# 22913  22913  2020-08-12T17:00:00     ITA           5     Veneto
# 22914  22914  2020-08-12T17:00:00     ITA           5     Veneto
# 22915  22915  2020-08-12T17:00:00     ITA           5     Veneto
# 22916  22916  2020-08-12T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 22912            27                               Venezia
# 22913            28                                Padova
# 22914            29                                Rovigo
# 22915           899    Fuori Regione / Provincia Autonoma
# 22916           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 22912                   VE  45.434905  12.338452                2969
# 22913                   PD  45.406930  11.876087                4383
# ...

# %%
data = pd.read_csv(r'G:\my video lecture\projects\cv19.csv')

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13         Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17      Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          18        Calabria  38.905976
# 3    3  2020-02-24T18:00:00     ITA          15        Campania  40.839566
# 4    4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  16.594402                     0                      0
# 3  14.250850                     0                      0
# 4  11.341721                    10                      2
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 3586  3586  2020-08-12T17:00:00     ITA          19        Sicilia  38.115697
# 3587  3587  2020-08-12T17:00:00     ITA           9        Toscana  43.769231
# 3588  3588  2020-08-12T17:00:00     ITA          10         Umbria  43.106758
# 3589  3589  2020-08-12T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 3590  3590  2020-08-12T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 3586  13.362357                    43                      6
# 3587  11.255889                    15                      3
# 3588  12.388247                     9                      0
# 3589   7.320149                     5                      0
# 3590  12.338452                    33                      6
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# ...

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  3591.000000  3591.000000  3591.000000  3591.000000
# mean   1795.000000    11.857143    43.046293    12.225955
# std    1036.776736     6.274672     2.489127     2.659318
# min       0.000000     1.000000    38.115697     7.320149
# 25%     897.500000     7.000000    41.125596    11.121231
# 50%    1795.000000    12.000000    43.616760    12.388247
# 75%    2692.500000    17.000000    45.434905    13.768136
# max    3590.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           3591.000000            3591.000000                3591.000000
# mean             460.956280              52.086884                 513.043163
# std             1347.956483             142.930582                1485.726449
# min                0.000000               0.000000                   0.000000
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x='Recovered',y='CurrentPositiveCases',data = data)

# %%
seaborn.relplot(x='Recovered',y='CurrentPositiveCases',data = data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1c702ce6ee77> in <module>
# ----> 1 seaborn.relplot(x='Recovered',y='CurrentPositiveCases',data = data)
#
# NameError: name 'seaborn' is not defined

# %%
sns.relplot(x='Recovered',y='CurrentPositiveCases',data = data)

# %%
sns.pairplot(data)
# Out:
# C:\Users\nihal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\nihal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.relplot(x='Deaths',y='TotalPositiveCases',kind='line',data = data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.catplot(x='TestsPerformed',y='Recovered',data= data)
